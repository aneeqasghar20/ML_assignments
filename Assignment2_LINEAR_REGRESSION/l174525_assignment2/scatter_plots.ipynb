# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('D:\Fall_2020\Applied_Machine_Learning\Assignment_2\kc_house_data.csv')
train_df=pd.read_csv('D:\Fall_2020\Applied_Machine_Learning\Assignment_2\kc_house_train_data.csv')
test_df=pd.read_csv('D:\Fall_2020\Applied_Machine_Learning\Assignment_2\kc_house_test_data.csv')
df.head(5)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
plt.scatter(train_df.sqft_living,train_df.price)
plt.xlabel("sqft_living")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.bedrooms,train_df.price)
plt.xlabel("Bedroom")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.bathrooms,train_df.price)
plt.xlabel("Bathrooms")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.sqft_lot,train_df.price)
plt.xlabel("sqft_lot")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.floors,train_df.price)
plt.xlabel("sqft_living")
plt.ylabel("Floors")
# Out:
# Text(0, 0.5, 'Floors')

# %%
plt.scatter(train_df.waterfront,train_df.price)
plt.xlabel("Waterfront")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.view,train_df.price)
plt.xlabel("View")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.condition,train_df.price)
plt.xlabel("Condition")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.grade,train_df.price)
plt.xlabel("Grade")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.sqft_above,train_df.price)
plt.xlabel("sqft_above")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.sqft_basement,train_df.price)
plt.xlabel("sqft_basement")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.yr_built,train_df.price)
plt.xlabel("yr_built")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.yr_renovated,train_df.price)
plt.xlabel("yr_renovated")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.zipcode,train_df.price)
plt.xlabel("Zipcode")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.lat,train_df.price)
plt.xlabel("lat")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.long,train_df.price)
plt.xlabel("Long")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.sqft_living15,train_df.price)
plt.xlabel("sqft_living15")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.sqft_lot15,train_df.price)
plt.xlabel("sqft_lot15")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.id,train_df.price)
plt.xlabel("ID")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
plt.scatter(train_df.date,train_df.price)
plt.xlabel("Date")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')
